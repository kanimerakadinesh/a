# %% [markdown]
# <a href="https://colab.research.google.com/github/kanimerakadinesh/a/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# Load the dataset
dataset = pd.read_csv(
    "/content/age_salary_dataset.csv")
#Printing the dataset
dataset
# Out:
#      Age   Salary
# 0   50.0  45056.0
# 1   36.0  72482.0
# 2   29.0  87716.0
# 3   42.0  48110.0
# 4   40.0  53773.0
# ..   ...      ...
# 95  58.0  57675.0
# 96  56.0  92733.0
# 97  43.0  84417.0
# 98  48.0  63938.0
# 99  56.0  63664.0
#
# [100 rows x 2 columns]

# %%
#Extracting independent variable(X)
#and dependent (Y) variables
X= dataset.iloc[:,:-1].values
Y= dataset.iloc[:,-1].values
print('independent variable(X):',X)
print('dependent variable(Y):',Y)
# Out:
# independent variable(X): [[50.]
#  [36.]
#  [29.]
#  [42.]
#  [40.]
#  [44.]
#  [32.]
#  [32.]
#  [45.]
#  [57.]
#  [45.]
#  [24.]
#  [43.]
#  [23.]
#  [45.]
#  [51.]
#  [59.]
#  [23.]
#  [42.]
#  [54.]
#  [33.]
#  [43.]
#  [nan]
#  [48.]
#  [49.]
#  [37.]
#  [36.]
#  [24.]
#  [58.]
#  [28.]
#  [42.]
#  [30.]
#  [39.]
#  [25.]
#  [46.]
#  [nan]
#  [30.]
#  [47.]
#  [23.]
#  [41.]
#  [49.]
#  [28.]
#  [29.]
#  [nan]
#  [35.]
#  [38.]
#  [57.]
#  [25.]
#  [23.]
#  [27.]
#  [25.]
#  [50.]
#  [39.]
#  [47.]
#  [55.]
#  [31.]
#  [57.]
#  [35.]
#  [52.]
#  [36.]
#  [29.]
#  [35.]
#  [44.]
#  [42.]
#  [37.]
#  [39.]
#  [45.]
#  [47.]
#  [46.]
#  [50.]
#  [36.]
#  [22.]
#  [46.]
#  [28.]
#  [30.]
#  [45.]
#  [22.]
#  [29.]
#  [45.]
#  [32.]
#  [38.]
#  [29.]
#  [56.]
#  [56.]
#  [54.]
#  [26.]
#  [49.]
#  [28.]
#  [30.]
#  [29.]
#  [33.]
#  [55.]
#  [54.]
#  [44.]
#  [45.]
#  [58.]
#  [56.]
#  [43.]
#  [48.]
#  [56.]]
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="mean")
X = imp.fit_transform(X)
Y = Y.reshape(-1,1)
Y = imp.fit_transform(Y)
Y = Y.reshape(-1)
print(X)
print(Y)
# Out:
# [[50.        ]
#  [36.        ]
#  [29.        ]
#  [42.        ]
#  [40.        ]
#  [44.        ]
#  [32.        ]
#  [32.        ]
#  [45.        ]
#  [57.        ]
#  [45.        ]
#  [24.        ]
#  [43.        ]
#  [23.        ]
#  [45.        ]
#  [51.        ]
#  [59.        ]
#  [23.        ]
#  [42.        ]
#  [54.        ]
#  [33.        ]
#  [43.        ]
#  [39.88659794]
#  [48.        ]
#  [49.        ]
#  [37.        ]
#  [36.        ]
#  [24.        ]
#  [58.        ]
#  [28.        ]
#  [42.        ]
#  [30.        ]
#  [39.        ]
#  [25.        ]
#  [46.        ]
#  [39.88659794]
#  [30.        ]
#  [47.        ]
#  [23.        ]
#  [41.        ]
#  [49.        ]
#  [28.        ]
#  [29.        ]
#  [39.88659794]
#  [35.        ]
#  [38.        ]
#  [57.        ]
#  [25.        ]
#  [23.        ]
#  [27.        ]
#  [25.        ]
#  [50.        ]
#  [39.        ]
#  [47.        ]
#  [55.        ]
#  [31.        ]
#  [57.        ]
#  [35.        ]
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="median")
X = imp.fit_transform(X)
Y = Y.reshape(-1,1)
Y = imp.fit_transform(Y)
Y = Y.reshape(-1)
print(X)
print(Y)
# Out:
# [[50.        ]
#  [36.        ]
#  [29.        ]
#  [42.        ]
#  [40.        ]
#  [44.        ]
#  [32.        ]
#  [32.        ]
#  [45.        ]
#  [57.        ]
#  [45.        ]
#  [24.        ]
#  [43.        ]
#  [23.        ]
#  [45.        ]
#  [51.        ]
#  [59.        ]
#  [23.        ]
#  [42.        ]
#  [54.        ]
#  [33.        ]
#  [43.        ]
#  [39.88659794]
#  [48.        ]
#  [49.        ]
#  [37.        ]
#  [36.        ]
#  [24.        ]
#  [58.        ]
#  [28.        ]
#  [42.        ]
#  [30.        ]
#  [39.        ]
#  [25.        ]
#  [46.        ]
#  [39.88659794]
#  [30.        ]
#  [47.        ]
#  [23.        ]
#  [41.        ]
#  [49.        ]
#  [28.        ]
#  [29.        ]
#  [39.88659794]
#  [35.        ]
#  [38.        ]
#  [57.        ]
#  [25.        ]
#  [23.        ]
#  [27.        ]
#  [25.        ]
#  [50.        ]
#  [39.        ]
#  [47.        ]
#  [55.        ]
#  [31.        ]
#  [57.        ]
#  [35.        ]
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="mode")
X = imp.fit_transform(X)
Y = Y.reshape(-1,1)
Y = imp.fit_transform(Y)
Y = Y.reshape(-1)
print(X)
print(Y)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-8-d6ad2f5cf4c6> in <cell line: 3>()
#       1 from sklearn.impute import SimpleImputer
#       2 imp=SimpleImputer(missing_values=np.nan,strategy="mode")
# ----> 3 X = imp.fit_transform(X)
#       4 Y = Y.reshape(-1,1)
#       5 Y = imp.fit_transform(Y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
# ...

# %%
combined_df = pd.DataFrame(combined_data,columns=list(dataset.columns))
combined_df.to_excel("/content/combined_data.xlsx",index=False)
print("Combined DataFrame:")
print(combined_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b96ff54e0068> in <cell line: 1>()
# ----> 1 combined_df = pd.DataFrame(combined_data,columns=list(dataset.columns))
#       2 combined_df.to_excel("/content/combined_data.xlsx",index=False)
#       3 print("Combined DataFrame:")
#       4 print(combined_df.head())
#
# NameError: name 'combined_data' is not defined

# %%
X_df=pd.DataFrame(X,columns=dataset.columns[:-1])
Y_df=pd.DataFrame(Y,columns=[dataset.columns[-1]])
combined_data=pd.concat([X_df,Y_df],axis=1)
print("combined data:")
print(combined_data)
# Out:
# combined data:
#      Age   Salary
# 0   50.0  45056.0
# 1   36.0  72482.0
# 2   29.0  87716.0
# 3   42.0  48110.0
# 4   40.0  53773.0
# ..   ...      ...
# 95  58.0  57675.0
# 96  56.0  92733.0
# 97  43.0  84417.0
# 98  48.0  63938.0
# 99  56.0  63664.0
#
# [100 rows x 2 columns]

# %%
combined_df = pd.DataFrame(combined_data,columns=list(dataset.columns))
combined_df.to_excel("/content/combined_data.xlsx",index=False)
print("Combined DataFrame:")
print(combined_df.head())
# Out:
# Combined DataFrame:
#     Age   Salary
# 0  50.0  45056.0
# 1  36.0  72482.0
# 2  29.0  87716.0
# 3  42.0  48110.0
# 4  40.0  53773.0
